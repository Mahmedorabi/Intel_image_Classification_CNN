# %%
import numpy as np 
import os 
import pathlib 
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import *

# %%
train_path="D:/Project AI/intel/seg_train/seg_train"
test_path="D:/Project AI/intel/seg_test/seg_test"

# %%
classes_name=os.listdir(train_path)
classes_name
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
def plot_image(class_name):
    plt.figure(figsize=(15,10))
    for i,category in enumerate(class_name):
        image_path=train_path+'/'+category
        image_in_folder=os.listdir(image_path)
        
        first_image=image_in_folder[1]
        first_image_path=image_path+'/'+first_image
        
        img=image.load_img(first_image_path)
        img_arr=image.img_to_array(img)/255
        
        plt.subplot(2,3,i+1)
        plt.imshow(img_arr)
        plt.title(category)
        plt.axis('off')
    plt.show()

# %%
plot_image(classes_name)

# %%
data_generator=ImageDataGenerator(rescale=1/255)

# %%
train_data=data_generator.flow_from_directory(train_path,
                                             target_size=(150,150),
                                             batch_size=128,
                                             shuffle=True)
# Out:
# Found 14034 images belonging to 6 classes.

# %%
test_data=data_generator.flow_from_directory(test_path,
                                            target_size=(150,150),
                                            batch_size=32,
                                            shuffle=True)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
model=Sequential()

model.add(Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',input_shape=[150,150,3]))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(.20))

model.add(Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(.30))

model.add(Conv2D(filters=128,kernel_size=3,padding='same',activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(.40))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))

model.add(Dense(6,activation='softmax'))
# Out:
# c:\Users\Mohamed orabi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
model_hist=model.fit(train_data,validation_data=test_data,epochs=10)
# Out:
# Epoch 1/10
# c:\Users\Mohamed orabi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - accuracy: 0.4864 - loss: 5.5154 - val_accuracy: 0.1740 - val_loss: 3.4641
# Epoch 2/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 173s 2s/step - accuracy: 0.7516 - loss: 0.7094 - val_accuracy: 0.1817 - val_loss: 3.8895
# Epoch 3/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.8061 - loss: 0.5505 - val_accuracy: 0.3513 - val_loss: 2.6218
# Epoch 4/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.8232 - loss: 0.4965 - val_accuracy: 0.4247 - val_loss: 2.5308
# Epoch 5/10
# ...

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
fig.suptitle("Model Preformance Visualization",fontsize=20)
ax[0].plot(model_hist.history['loss'],label='Training Loss')
ax[0].plot(model_hist.history['val_loss'],label='Testing Loss')
ax[0].set_title('Training Loss VS. Testing Loss')
ax[0].legend()

ax[1].plot(model_hist.history['accuracy'],label='Training Accuracy')
ax[1].plot(model_hist.history['val_accuracy'],label='Testing Accuracy')
ax[1].set_title('Training Accuracy VS. Testing Accuracy')
ax[1].legend()
plt.show()

# %%
loss,acc=model.evaluate(train_data)
print(f'Accuracy of Training data is: {acc*100}')
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 23s 210ms/step - accuracy: 0.9115 - loss: 0.2488
# Accuracy of Training data is: 90.95767140388489

# %%
loss,acc=model.evaluate(test_data)
print(f'Accuracy of Testing data is: {acc*100}')
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - accuracy: 0.7924 - loss: 0.7971
# Accuracy of Testing data is: 79.60000038146973

# %%
class_map=dict([value,key]for key,value in train_data.class_indices.items())
class_map
# Out:
# {0: 'buildings',
#  1: 'forest',
#  2: 'glacier',
#  3: 'mountain',
#  4: 'sea',
#  5: 'street'}

# %%
test_img="D:/Project AI/intel/seg_pred/seg_pred/171.jpg"

# %%
def predication_image(testing_image,actual_label):
    test_image=image.load_img(testing_image,target_size=(150,150))
    test_image_arr=image.img_to_array(test_image)/255
    predict_img=test_image_arr.reshape((1,test_image_arr.shape[0],test_image_arr.shape[1],test_image_arr.shape[2]))
    
    predict_image=np.argmax(model.predict(predict_img))
    predict_label=class_map[predict_image]
    
    plt.figure(figsize=(10,5))
    plt.imshow(test_image_arr)
    plt.title(f'Acatual Label is: {actual_label} | Predicat label is: {predict_label}')
    plt.grid()
    plt.axis('off')
    plt.show()

# %%
predication_image(test_img,'Sea')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
test_img="D:/Project AI/intel/seg_pred/seg_pred/173.jpg"

# %%
predication_image(test_img,'Mountain')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
test_img="D:/Project AI/intel/seg_pred/seg_pred/957.jpg"

# %%
predication_image(test_img,'Forest')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
